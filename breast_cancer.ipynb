# %%
# Importing the necessary libraries
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import pandas as pd

# Load the CSV file
file_path = r"C:\Users\Student\Desktop\New folder (3)\data.csv"  # Use raw string to handle backslashes
data = pd.read_csv(file_path)

# Display the first few rows of the dataframe
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Display basic information about the dataframe
data.info()

# Display summary statistics
data.describe()

# Check for missing values
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
# Display basic information about the dataframe
data.info()

# Display summary statistics
data.describe()

# Check for missing values
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
# Fill missing values for numerical columns with the median
numeric_cols = data.select_dtypes(include=['number']).columns  # Select only numeric columns
data[numeric_cols] = data[numeric_cols].fillna(data[numeric_cols].median())

# Handle categorical columns separately (if applicable)
# Assuming your dataframe might have a categorical column 'Category'
if 'Category' in data.columns:
    data['Category'] = data['Category'].astype('category').cat.codes

# %%
# Breast Cancer Data Analysis

## Cell 1: Import Libraries
import pandas as pd

## Cell 2: Load the CSV File
file_path = r"C:\Users\Student\Desktop\New folder (3)\data.csv" 
data = pd.read_csv(file_path)
print(data.head())  # Preview data

## Cell 3: Explore the Data
data.info() 
data.describe()
missing_values = data.isnull().sum()
print(missing_values)

# Check column names to confirm the presence of the target column
print(data.columns.tolist())

## Cell 4: Data Preprocessing
# Fill missing values for numeric columns only
numeric_cols = data.select_dtypes(include='number').columns
data[numeric_cols] = data[numeric_cols].fillna(data[numeric_cols].median())

# Convert 'diagnosis' column to binary
data['diagnosis'] = data['diagnosis'].map({'B': 0, 'M': 1})  # Convert 'B' and 'M' to 0 and 1

# Drop the unwanted column if it exists
data.drop(columns=['Unnamed: 32'], inplace=True, errors='ignore')  # Drop if it exists

## Cell 5: Use Data for Machine Learning or Analysis
target_column = 'diagnosis'  # Use the actual diagnosis column as target

if target_column in data.columns:
    X = data.drop(columns=[target_column])  # Features
    y = data[target_column]                   # Target variable
else:
    print(f"Column '{target_column}' not found!")
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...
